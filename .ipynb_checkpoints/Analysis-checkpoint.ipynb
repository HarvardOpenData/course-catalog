# %%
data = None

with open('fas_crse_cat.txt', 'r') as f:
    raw_content = f.read()
    data = f.read().splitlines()

# %%
from bs4 import BeautifulSoup

# %%
raw_content

with open('fas_crse_cat.html', 'r') as f:
    raw_content = f.read()
    
soup = BeautifulSoup(raw_content, 'html.parser')

# %%
# all content will be in div.t
# so extract this
elts = soup.find_all('div', class_='t')

""
# Out:
# ''

# %%
# the .fs2 will be the title
# following .fs3 will be descriptive strings

groups = []
current_group = None

for elt in elts:    
    if 'fs2' in elt['class']:
        # .fs2 marks course titles
        
        # first, ensure there's something actually here
        # FIXME could be bugs here from page breaks
        if elt.string is None or elt.string.strip() == "":
            continue
            
        # ignore table of contents
        
        # start a new group
        current_group = dict()
        groups.append(current_group)
        
        current_group['name'] = elt.string
        current_group['strings'] = []
    elif elt is not None:
        # these are probably .fs{3,4,5,...}
        # these are descriptive strings
        
        # error checking
        if current_group is None:
            continue
        if elt.string is None:
            continue
            
        # remove page footers
        BANNED_STRINGS = (
            'HARVARD UNIVERSITY',
            '9/4/2017 0:39 AM',
            '9/24/2017 0:39 AM',
            'HARVARD UNIVERSITY 9/24/2017 0:39 AM'
        )
        if elt.string in BANNED_STRINGS:
            continue
            
        current_group['strings'].append(elt.string)

# %%
import re 

for group in groups[0:10]:
    # try to extract a course schedule
    times = []
    for string in group['strings']:
        matcher = re.compile("[MTWRF]{1,5} \d{4} [AP]M - \d{4} [AP]M")
        times.append(matcher.findall(string))
        
    flattened_times = sum(times,[])
    
    # this array will have max 1 element
    if len(flattened_times) > 0:
        group['schedule'] = flattened_times[0]
    else:
        group['schedule'] = None
    
    
    # try to extract a semester
    for string in group['strings']:
        semester = re.search("20\d\d ((Fall)|(Spring))", string)
        if semester is not None:
            # just find the first one then quit
            group['semester'] = semester.group()
            break
        
    # so prof name isn't necessarily the first line. but usually it has 2 spaces after it lol
    # e.g.
    #     """
    #      'semester': u'2017 Fall',
    #       'strings': [u'(123591)',
    #        u'Jacob Olupona  ',
    #        u'2017 Fall (4 Credits)',
    #        u'Schedule: ',
    #        u'R 0400 PM - 0559 PM',
    #        u'Instructor Permissions:',
    #        u'None',
    #     """
    # so we can regex for anything with 2 spaces at the end. hard to structure stuff before
        
#     # try to extract a schedule
#     for string in group['strings']:
#         # empty for now
#         group['schedule'] = None
        
#         # see if there's a course time, e.g. MW 10-12
#         time = get_time(string)
#         if time is not None:
#             # just find the first one then quit
#             group['schedule'] = time
#             break

# %%
groups[0:10]
# Out:
# [{'name': u'Table of Contents',
#   'schedule': None,
#   'strings': [u'African and African American Studies']},
#  {'name': u'Subject: Hausa', 'schedule': None, 'strings': []},
#  {'name': u'Hausa     AA ',
#   'schedule': None,
#   'semester': u'2017 Fall',
#   'strings': [u'John Mugane  ',
#    u'2017 Fall (4 Credits)',
#    u'Schedule: ',
#    u'TBD',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'A study of Hausa a most widely used native language and lingua franca in West Africa at the Elementary level (First',
#    u'year part 1). Contact hours supplemented by digital resources. Emphasis on written expression, reading ',
#    u'comprehension, and oral fluency. Students must complete both terms of this course (parts AA and AB) within the ',
#    u'same academic year in order to receive full Elementary Hausa course credit.',
#    u'Course Notes:',
#    u'Languages in the tutorial program are offered when there is demonstrated ',
#    u'curricular or academic need on the part of the student, and when suitable ',
#    u'instruction can be arranged.  Please contact the department to learn more.',
#    u'Additional Course Attributes:',
#    u' ',
#    u' ']},
#  {'name': u'Hausa     AB ',
#   'schedule': None,
#   'semester': u'2018 Spring',
#   'strings': [u'John Mugane  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'TBD',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'A study of Hausa a most widely used native language and lingua franca in West Africa at the Elementary level (First',
#    u'year part 2). Contact hours supplemented by language digital resources. Emphasis on written expression, reading ',
#    u'comprehension, and oral fluency. Students must complete both terms of this course (parts AA and AB) within the ',
#    u'same academic year in order to receive full Elementary Hausa course credit. This course is offered only in the ',
#    u'Spring.',
#    u'Course Notes:',
#    u'Languages in the tutorial program are offered when there is demonstrated ',
#    u'curricular or academic need on the part of the student, and when suitable ',
#    u'instruction can be arranged.  Please contact the department to learn more.',
#    u'Additional Course Attributes:']},
#  {'name': u'Hausa     BB ',
#   'schedule': None,
#   'semester': u'2018 Spring',
#   'strings': [u'John Mugane  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'TBD',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'A study of Hausa a most widely used native language and lingua franca in West Africa at the Intermediate level ',
#    u'(Second year part 2). Contact hours supplemented by digital resources sessions. Emphasis on written expression, ',
#    u'reading comprehension, and oral fluency. Students must complete both terms of this course (parts BA and BB) ',
#    u'within the same academic year in order to receive full Intermediate Hausa course credit. Students taking Hausa BA ',
#    u'in the Spring must note that Hausa BB is offered only in the Spring.  ',
#    u'Course Notes:',
#    u'Languages in the tutorial program are offered when there is demonstrated ',
#    u'curricular or academic need on the part of the student, and when suitable ',
#    u'instruction can be arranged.  Please contact the department to learn more.',
#    u'Additional Course Attributes:']},
#  {'name': u'Hausa  101AR ',
#   'schedule': None,
#   'semester': u'2017 Fall',
#   'strings': [u'Advanced Hausa',
#    u'John Mugane  ',
#    u'2017 Fall (4 Credits)',
#    u'Schedule: ',
#    u'TBD',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'A study of Hausa a most widely used native language and lingua franca in West Africa at the Advanced level in the ',
#    u'Fall semester. As needed, successive advanced readings in Hausa may be taken under Hausa 101ar every Fall.',
#    u'Course Notes:',
#    u'Languages in the tutorial program are offered when there is demonstrated ',
#    u'curricular or academic need on the part of the student, and when suitable ',
#    u'instruction can be arranged.  Please contact the department to learn more.',
#    u'Recommended Prep:',
#    u'Hausa B or equivalent',
#    u'Additional Course Attributes:',
#    u' ',
#    u' ']},
#  {'name': u'Hausa  101BR ',
#   'schedule': None,
#   'semester': u'2018 Spring',
#   'strings': [u'John Mugane  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'TBD',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'A study of Hausa a most widely used native language and lingua franca in West Africa at the Advanced level in the ',
#    u'Spring semester. As needed, successive advanced readings in Hausa may be taken under Hausa 101br every ',
#    u'Spring.',
#    u'Course Notes:',
#    u'Languages in the tutorial program are offered when there is demonstrated ',
#    u'curricular or academic need on the part of the student, and when suitable ',
#    u'instruction can be arranged.  Please contact the department to learn more.',
#    u'Recommended Prep:',
#    u'Hausa 101ar or equivalent.',
#    u'Additional Course Attributes:']},
#  {'name': u'Subject: African & African Amer Studies',
#   'schedule': None,
#   'strings': [u' ', u' ']},
#  {'name': u'African & African Amer Studies   10 ',
#   'schedule': u'MW 1100 AM - 1159 AM',
#   'semester': u'2018 Spring',
#   'strings': [u'Henry Gates  ',
#    u'Lawrence Bobo  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'MW 1100 AM - 1159 AM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'An exploration of some of the key texts and issues in African American Studies from a range of disciplinary ',
#    u'perspectives. Members of the faculty deliver guest lectures in their own areas of specialization.',
#    u'Course Notes:',
#    u'Required of concentrators in the African American Studies track. Students ',
#    u'who transfer into the concentration after their sophomore year may ',
#    u'substitute another African and African American Studies course already ',
#    u'taken if they satisfy the Director of Undergraduate Studies that it establishes ',
#    u'a basic familiarity with the materials covered in African and African American',
#    u'Studies 10. This course, when taken for a letter grade, meets the General ',
#    u'Education requirement for United States in the World. This course fulfills the ',
#    u'requirement that one of the eight General Education courses also engage ',
#    u'substantially with Study of the Past.',
#    u'Additional Course Attributes:']},
#  {'name': u'African & African Amer Studies   11 ',
#   'schedule': u'R 0400 PM - 0559 PM',
#   'semester': u'2017 Fall',
#   'strings': [u'(123591)',
#    u'Jacob Olupona  ',
#    u'2017 Fall (4 Credits)',
#    u'Schedule: ',
#    u'R 0400 PM - 0559 PM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'This course introduces students to the general outlines of African archeology, history and geography, as well as key',
#    u'concepts in the study of African health, social life , economic situation, arts, and politics. Our aim is to give students ',
#    u'a fundamental vocabulary and interdisciplinary methodology for the study of Africa. Throughout, we assume that ',
#    u'Africa is not a unique isolate but a continent bubbling with internal diversity, historical change, and cultural ',
#    u'connections beyond its shores. The course is open to all students who are interested in exploring various ',
#    u'dimensions of African life and cultures in ancient and modern periods.',
#    u'Course Notes:',
#    u'Required of concentrators in African Studies track. This course, when taken ',
#    u'for a letter grade, meets the General Education requirement for Societies of ',
#    u'the World.',
#    u'Additional Course Attributes:']}]

# %%
# dump data to file

import json
with open('courses_rough.json', 'w') as outfile:
    json.dump(groups, outfile)

# %%
# TODO: extract more info

# %%
# caleb's analysis
# turns it into numbers
def get_time(contents):
    matcher = re.compile("[MTWRF]{1,5} \d{4} [AP]M - \d{4} [AP]M")
    times = matcher.findall(contents)

    submatcher = re.compile("([MTWRF]{1,5}) (\d{4}) ([AP]M) - (\d{4}) ([AP]M)")

    for time in times:
        timeTuple = submatcher.findall(time)[0]
        newTime = [timeTuple[0], int(timeTuple[1]), int(timeTuple[3])]
        if timeTuple[2] == "PM" and timeTuple[1][0:2] != "12":
            newTime[1] += 1200
        if timeTuple[4] == "PM" and timeTuple[3][0:2] != "12":
            newTime[2] += 1200
        newTime[1] = 60 * (newTime[1] // 100) + (newTime[1] % 100)
        newTime[2] = 60 * (newTime[2] // 100) + (newTime[2] % 100)
        
        return dict(
            days=newTime[0],
            start=newTime[1],
            end=newTime[2]
        )

        return newTime
    
    # no times found
    return None

# %%
get_time("R 0400 PM - 0559 PM")
# Out:
# {'days': 'R', 'end': 1079, 'start': 960}

# %%
print get_time("TBD")
# Out:
# None

# %%
start = 1204
groups[(start):(start+20)]
# Out:
# [{'name': u'Computer Science  221 ',
#   'strings': [u'Madhu Sudan  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'TR 0230 PM - 0359 PM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'A quantitative theory of the resources needed for computing and the impediments to efficient computation. The ',
#    u'models of computation considered include ones that are finite or infinite, deterministic, randomized, quantum or ',
#    u'nondeterministic, discrete or algebraic, sequential or parallel.',
#    u'Recommended Prep:',
#    u'Computer Science 121 or equivalent.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  226 ',
#   'strings': [u'Jelani Nelson  ',
#    u'2017 Fall (4 Credits)',
#    u'Schedule: ',
#    u'TR 0230 PM - 0359 PM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'Big data is data so large that it does not fit in the main memory of a single machine. The need to process big data ',
#    u'by space-efficient algorithms arises in Internet search, machine learning, network traffic monitoring, scientific ',
#    u'computing, signal processing, and other areas. This course will cover mathematically rigorous models for ',
#    u'developing such algorithms, as well as some provable limitations of algorithms operating in those models. Some ',
#    u'topics covered include streaming algorithms, dimensionality reduction and sketching, randomized algorithms for ',
#    u'numerical linear algebra, sparse recovery and the sparse Fourier transform.  The course will also cover some ',
#    u'applications of these methods.',
#    u'Recommended Prep:',
#    u'CS 124; knowledge of discrete probability and linear algebra.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  227R ',
#   'strings': [u'Boaz Barak  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'TR 1000 AM - 1129 AM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'Cryptography is as old as human communication itself, but has undergone a revolution in the last few decades. It is ',
#    u'now about much more than "secret writing" and includes seemingly paradoxical notions such as communicating ',
#    u'securely without a shared secret, and computing on encrypted data. In this challenging but rewarding course we will',
#    u'start from the basics of private and public key cryptography and go all the way up to advanced notions such as fully ',
#    u'homomorphic encryption and software obfuscation. This is a proof-based course that will be best appreciated by ',
#    u'mathematically mature students.',
#    u'Course Notes:',
#    u'This course will be offered in both an undergraduate and graduate versions. ',
#    u'The graduate version will involve an additional project.',
#    u'Recommended Prep:',
#    u'Comfort with mathematical proofs at the level of CS121, CS124 or similar. ',
#    u'Please contact the instructor if you&apos;re unsure if your background is sufficient.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  228 ',
#   'strings': [u'Leslie Valiant  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'TR 0230 PM - 0359 PM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'Possibilities of and limitations to performing learning by computational agents. Topics include computational ',
#    u'models, polynomial time learnability, learning from examples and learning from queries to oracles. Applications to ',
#    u'Boolean functions, automata and geometric functions.',
#    u'Recommended Prep:',
#    u'Computer Science 121 or equivalent.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  229R ',
#   'strings': [u'Mrinal Kumar  ',
#    u'2017 Fall (4 Credits)',
#    u'Schedule: ',
#    u'F 1000 AM - 1259 PM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'The goal of this course is to provide an introduction to the area of Arithmetic Circuit Complexity and to try and get a ',
#    u'sense of the power and limitations of arithmetic circuits as a computational model. We hope to see a combination of',
#    u'both classical and recent results in this area, including some upper bounds, lower bounds and questions about ',
#    u'factoring and derandomization. ',
#    u'A more detailed description of the course, and tentative content can be found at ',
#    u'https://mrinalkr.bitbucket.io/arithmeticcktsF17.html',
#    u'Recommended Prep:',
#    u'CS 121/124/125 or equivalents.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  234R ',
#   'strings': [u'Topics on Computation in Networks and Crowds',
#    u'Yaron Singer  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'TBD',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'Topics on the design and analysis of algorithms, processes, and systems related to crowds and social networks. ',
#    u'Readings in AI, theoretical CS, machine learning, social science theory, economic theory, and operations research.',
#    u'Recommended Prep:',
#    u'Mathematics 21b, Applied Mathematics 21b, or equivalent; Computer ',
#    u'Science 124, and 181 or 182, or equivalents; or permission of instructor.',
#    u'Additional Course Attributes:',
#    u' ',
#    u' ']},
#  {'name': u'Computer Science  234R ',
#   'strings': [u'(109667)',
#    u'Nicole Immorlica  ',
#    u'2017 Fall (4 Credits)',
#    u'Schedule: ',
#    u'F 0900 AM - 1159 AM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'Topics on the design and analysis of algorithms, processes, and systems related to crowds and social networks. ',
#    u'Readings in AI, theoretical CS, machine learning, social science theory, economic theory, and operations research.',
#    u'Recommended Prep:',
#    u'Mathematics 21b, Applied Mathematics 21b, or equivalent; Computer ',
#    u'Science 124, and 181 or 182, or equivalents; or permission of instructor.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  236R ',
#   'strings': [u'Yiling Chen  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'MW 0100 PM - 0229 PM',
#    u'Instructor Permissions:',
#    u'Instructor',
#    u'Enrollment Cap:',
#    u'20',
#    u'Interplay between computation and economics. Topics in electronic commerce, computational social choice, ',
#    u'computational mechanism design, peer production, prediction markets and reputation systems. Readings in AI, ',
#    u'theoretical CS, multi-agent systems, economic theory, and operations research.',
#    u'Recommended Prep:',
#    u'Mathematics 21b, Applied Mathematics 21b, or equivalent; Economics ',
#    u'1011a, or equivalent; or permission of instructor.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  244R ',
#   'strings': [u'Networks Design Projects',
#    u'H. Kung  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'MW 0230 PM - 0359 PM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'The contents and course requirements are similar to those of Computer Science 144r, with the exception that ',
#    u'students enrolled in Computer Science 244r are expected to do substantial system implementation and perform ',
#    u'graduate-level work.',
#    u'Course Notes:',
#    u'Preference given to upper-class undergraduates or graduate students in ',
#    u'computer science or in business who are proficient in computer ',
#    u'programming or in business software.',
#    u'Recommended Prep:',
#    u'Programming experience (CS 50 should be fine) and interest in the subject ',
#    u'matter. Importantly, CS 143 is NOT a prerequisite. Labs and extra support ',
#    u'will provide intensive preparation in the first weeks of the semester to help ',
#    u'students quickly obtain the networking background necessary to excel in the',
#    u'course.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  248 ',
#   'strings': [u'Gu-Yeon Wei  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'TR 1130 AM - 1259 PM',
#    u'Instructor Permissions:',
#    u'Instructor',
#    u'Enrollment Cap:',
#    u'16',
#    u'The contents and course requirements are similar to those of Computer Science 148, with the exception that ',
#    u'students enrolled in Computer Science 248 are expected to do a substantial design project and paper discussions ',
#    u'on advanced topics.',
#    u'Course Notes:',
#    u'Offered in alternate years.',
#    u'Recommended Prep:',
#    u'Computer Science 141 or permission of instructor.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  252R ',
#   'strings': [u'Stephen Chong  ',
#    u'2017 Fall (4 Credits)',
#    u'Schedule: ',
#    u'MW 1130 AM - 1259 PM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'Seminar course exploring recent research in programming languages. Topics vary from year to year. Students read ',
#    u'and present research papers, undertake a research project.',
#    u'Recommended Prep:',
#    u'Computer Science 152 or permission of the instructor.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  260R ',
#   'strings': [u'Eddie Kohler  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'MW 0100 PM - 0229 PM',
#    u'Instructor Permissions:',
#    u'Instructor',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'Modern software systems construction and analysis. Distributed systems; operating systems; networks; data ',
#    u'centers; big data; emerging systems deployments. Close, careful reading of research papers and code, coupled ',
#    u'with programming projects. Readability and programmability. Topic focus will change each offering. May be ',
#    u'repeated for credit with instructor permission.',
#    u'Recommended Prep:',
#    u'Programming experience and instructor permission.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  262 ',
#   'strings': [u'Introduction to Distributed Computing',
#    u'James Waldo  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'MW 1130 AM - 1259 PM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'An examination of the special problems associated with distributed computing such as partial failure, lack of global ',
#    u'knowledge, asynchrony and coordination of time, and protocols that function in the face of these problems. ',
#    u'Emphasis on both the theory that grounds thinking about these systems and in the ways to design and build such ',
#    u'systems.',
#    u'Recommended Prep:',
#    u'Computer Science 161 or permission of instructor.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  263 ',
#   'strings': [u'James Mickens  ',
#    u'2017 Fall (4 Credits)',
#    u'Schedule: ',
#    u'TR 0100 PM - 0229 PM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'This course explores practical attacks on modern computer systems, explaining how those attacks can be mitigated',
#    u'using careful system design and the judicious application of cryptography. The course discusses topics like buffer ',
#    u'overflows, web security, information flow control, and anonymous communication mechanisms such as Tor. The ',
#    u'course includes several small projects which give students hands-on experience with various offensive and ',
#    u'defensive techniques; the final, larger project is open-ended and driven by student interests.',
#    u'Recommended Prep:',
#    u'Computer Science 161 (Operating Systems)',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  265 ',
#   'strings': [u'Stratos Idreos  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'WF 0400 PM - 0529 PM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'Big data is everywhere. A fundamental goal across numerous modern businesses and sciences is to be able to ',
#    u'exploit as many machines as possible, to consume as much information as possible and as fast as possible. The ',
#    u'big challenge is "how to turn data into useful knowledge". This is far from a simple task and a moving target as both ',
#    u'the underlying hardware and our ability to collect data evolve. In this class, we will discuss how to design data ',
#    u'systems and algorithms that can "scale up" and "scale out". Scale up refers to the ability to use a single machine to ',
#    u'all its potential, i.e., to exploit properly the memory hierarchy and the multiple CPU and GPU cores. Scale out refers ',
#    u'to the ability to use more than 1 machines (typically 100s or 1000s) effectively. This is a research oriented class. ',
#    u'Every week we will read two modern research papers; one from the scale up area and one from the scale out area. ',
#    u'We will use examples from several areas, including relational systems and distributed databases, graph processing ',
#    u'systems (i.e., for social networks), key value stores, noSQL and newSQL systems as well as mobile computing. ',
#    u'Each student will work on a semester long data systems research project (in groups of 2-4 students) which can be ',
#    u'in any of the above areas and will be based on an open research problem.',
#    u'Recommended Prep:',
#    u'CS 165 or permission of instructor.',
#    u'Additional Course Attributes:',
#    u' ',
#    u' ']},
#  {'name': u'Computer Science  279 ',
#   'strings': [u'Krzysztof Gajos  ',
#    u'2017 Fall (4 Credits)',
#    u'Schedule: ',
#    u'TR 1000 AM - 1129 AM',
#    u'Instructor Permissions:',
#    u'Instructor',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'The course covers major areas of inquiry and core research methods in Human-Computer Interaction including ',
#    u'experimental design, statistical data analysis, and qualitative methods. Activities will include discussion of primary ',
#    u'literature, a small number of lectures, assignments (design, execution and analysis of both lab-based and on-line ',
#    u'experiments), and a research project. Special focus this year is on social computing and crowd-powered systems. ',
#    u'Specifically, we will look at the design and analysis of systems, in which crowds of intrinsically motivated volunteers ',
#    u'contribute to meaningful and non-trivial human computation tasks as a byproduct of doing something that they are ',
#    u'motivated to do anyway.',
#    u'Course Notes:',
#    u'Designed for first year grads from all areas. Advanced undergraduates ',
#    u'welcome, particularly those who wish to do research (or write a thesis) in an ',
#    u'area related to Human-Computer Interaction.',
#    u'Recommended Prep:',
#    u'None for graduate students; for undergrads CS 179 or CS 171 is strongly ',
#    u'recommended and permission of the instructor is required. Basic web ',
#    u'hacking is required to implement and deploy web-based experiments.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  281 ',
#   'strings': [u'Alexander Rush  ',
#    u'2017 Fall (4 Credits)',
#    u'Schedule: ',
#    u'MW 0100 PM - 0229 PM',
#    u'Instructor Permissions:',
#    u'Instructor',
#    u'Enrollment Cap:',
#    u'60',
#    u'Advanced statistical machine learning and probabilistic data analysis. Topics include: Variational inference, ',
#    u'graphical models, deep learning, text modeling, unsupervised learning, dimensionality reduction and visualization. ',
#    u'Requires a major final project.',
#    u'Recommended Prep:',
#    u'Students should feel comfortable with linear algebra and probability theory. ',
#    u'Students will be expected to implement algorithms in Python.',
#    u'Additional Course Attributes:',
#    u' ',
#    u' ']},
#  {'name': u'Computer Science  282R ',
#   'strings': [u'Finale Doshi-Velez  ',
#    u'2017 Fall (4 Credits)',
#    u'Schedule: ',
#    u'MW 0900 AM - 1029 AM',
#    u'Instructor Permissions:',
#    u'Instructor',
#    u'Enrollment Cap:',
#    u'20',
#    u'Sequential decision making is at the core of many healthcare problems: a clinician observes a patient, determines a',
#    u'treatment, and based on the response and the patient&apos;s previous history, determines what to try next.  ',
#    u'Reinforcement learning is a formal framework for thinking about such problems.  This course will first cover the ',
#    u'fundamentals of reinforcement learning through lectures, readings, and coding assignments.  Topics will include ',
#    u'Markov decision process and partially observable Markov decision processes, planning under uncertainty, model-',
#    u'free and model-based reinforcement learning, function approximation in reinforcement learning, and batch ',
#    u'reinforcement learning.  Students will also engage in a semester-long project applying these techniques to clinical ',
#    u'decision making in intensive care units.',
#    u'Recommended Prep:',
#    u'Students are expected to be fluent in basic linear algebra (matrix ',
#    u'manipulation), basic statistics (e.g. rules of expectations, importance ',
#    u'sampling), algorithms (e.g. dynamic programming), and software ',
#    u'engineering/numerical computing (e.g. programming in Python and numpy, ',
#    u'working with data with 100,000+ rows).',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  283 ',
#   'strings': [u'Computer Vision',
#    u' ',
#    u'(113944)',
#    u'Todd Zickler  ',
#    u'2017 Fall (4 Credits)',
#    u'Schedule: ',
#    u'TR 1130 AM - 1259 PM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'Vision as an ill-posed inverse problem: image formation, two-dimensional signal processing; feature analysis; image',
#    u'segmentation; color, texture, and shading; multiple-view geometry; object and scene recognition; and applications.',
#    u'Course Notes:',
#    u'Offered jointly with the Design School as SCI-06275.',
#    u'Additional Course Attributes:']},
#  {'name': u'Computer Science  284 ',
#   'strings': [u'Scott Kuindersma  ',
#    u'2018 Spring (4 Credits)',
#    u'Schedule: ',
#    u'TR 0230 PM - 0359 PM',
#    u'Instructor Permissions:',
#    u'None',
#    u'Enrollment Cap:',
#    u'n/a',
#    u'Numerical methods have revolutionized the way we control dynamic motions in complex robots. In this course, we ',
#    u'study a variety of optimization algorithms for designing and stabilizing trajectories for walking, manipulating, and ',
#    u'flying systems. Topics will include optimal control, nonlinear programming, trajectory planning and stabilization, ',
#    u'model-predictive control, Lyapunov analysis via sums-of-squares programming, legged systems, and estimation ',
#    u'and control through frictional contact. Students will gain practical experience implementing modern algorithms to ',
#    u'control a variety of simulated systems using the Drake MATLAB software toolbox.',
#    u'Recommended Prep:',
#    u'Linear algebra and multivariable calculus. Prior exposure to robotics and ',
#    u'dynamics is helpful, but not required. Students will be expected to complete ',
#    u'significant programming assignments in MATLAB.',
#    u'Additional Course Attributes:']}]
